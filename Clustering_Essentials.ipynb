# %% [markdown]
# https://machinelearningmastery.com/clustering-algorithms-with-python/

# %% [markdown]
# https://realpython.com/k-means-clustering-python/

# %% [markdown]
# https://stackoverflow.com/questions/34611038/grid-search-for-hyperparameter-evaluation-of-clustering-in-scikit-learn

# %% [markdown]
# https://stackoverflow.com/questions/25633383/how-can-gridsearchcv-be-used-for-clustering-meanshift-or-dbscan

# %% [markdown]
# https://stackoverflow.com/questions/49488313/kmeans-in-pipeline-with-gridsearchcv-scikit-learn

# %% [markdown]
# https://pypi.org/project/clusteval/

# %% [markdown]
# ## Visualize the results on PCA-reduced data:

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_digits.html#sphx-glr-auto-examples-cluster-plot-kmeans-digits-py

# %% [markdown]
# ## Selecting the number of clusters with silhouette analysis on KMeans clustering

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html#sphx-glr-auto-examples-cluster-plot-kmeans-silhouette-analysis-py

# %% [markdown]
# A list of 10 of the more popular algorithms is as follows:
#
# - Affinity Propagation
# - Agglomerative Clustering
# - BIRCH
# - DBSCAN
# - K-Means
# - Mini-Batch K-Means
# - Mean Shift
# - OPTICS
# - Spectral Clustering
# - Mixture of Gaussians

# %%
#!pip install clusteval

# %%
# synthetic classification dataset
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import Birch
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import MeanShift
from sklearn.cluster import OPTICS
from sklearn.cluster import SpectralClustering
from sklearn.mixture import GaussianMixture
from matplotlib import pyplot
from clusteval import clusteval

# %%
X, y = make_classification(
    n_samples=100,
    n_features=3,
    n_informative=3,
    n_redundant=0,
    n_clusters_per_class=3,
    random_state=7
)

# %%
# create scatter plot for samples from each class
for class_value in range(2):
    # get row indexes for samples with this class
    row_ix = where(y == class_value)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])

# show the plot
pyplot.show()

# %%
# define the model
model = AffinityPropagation(damping=0.9)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)

# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
# define the model
model = AgglomerativeClustering(n_clusters=2)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
model = Birch(threshold=0.01, n_clusters=2)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
model = DBSCAN(eps=0.30, min_samples=9)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
model = KMeans(n_clusters=2)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
model = MiniBatchKMeans(n_clusters=2)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
# Out:
# C:\Users\KonuTech\.conda\envs\tf-gpu\lib\site-packages\sklearn\cluster\_kmeans.py:1046: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 4096 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
model = MeanShift()
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
model = OPTICS(eps=0.8, min_samples=10)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
model = SpectralClustering(n_clusters=2)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
model = GaussianMixture(n_components=2)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
# Determine the optimal number of clusters

ce = clusteval(method='silhouette')
ce.fit(X)
ce.plot()
ce.dendrogram()
ce.scatter(X)
# Out:
# [clusteval] >Fit using agglomerative with metric: euclidean, and linkage: ward
# [clusteval] >Evaluate using silhouette.
# 100%|██████████| 23/23 [00:00<00:00, 821.50it/s]
# [clusteval] >Compute dendrogram threshold.
# [clusteval] >Optimal number clusters detected: [21].
# [clusteval] >Fin.
# [clusteval] >Plotting the dendrogram with optimized settings: metric=euclidean, linkage=ward, max_d=5.182. Be patient now..
# [clusteval] >Compute cluster labels.
# [clusteval] >Estimated number of n_clusters: 21, average silhouette_score=0.327

# %%
# Determine the optimal number of clusters
ce = clusteval(method='dbindex')
ce.fit(X)
ce.plot()
ce.scatter(X)
ce.dendrogram()
# Out:
# [clusteval] >Fit using agglomerative with metric: euclidean, and linkage: ward
# [clusteval] >Evaluate using dbindex.
# 100%|██████████| 23/23 [00:00<00:00, 302.65it/s]
# [clusteval] >Compute dendrogram threshold.
# [clusteval] >Optimal number clusters detected: [23].
# [clusteval] >Fin.
# [clusteval] >Estimated number of n_clusters: 23, average silhouette_score=0.323
# [clusteval] >Plotting the dendrogram with optimized settings: metric=euclidean, linkage=ward, max_d=3.691. Be patient now..
# [clusteval] >Compute cluster labels.
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [45.0, 45.0, 60.0, 60.0],
#   [35.0, 35.0, 52.5, 52.5],
#   [12.5, 12.5, 43.75, 43.75],
#   [85.0, 85.0, 95.0, 95.0],
#   [115.0, 115.0, 125.0, 125.0],
#   [105.0, 105.0, 120.0, 120.0],
#   [90.0, 90.0, 112.5, 112.5],
#   [75.0, 75.0, 101.25, 101.25],
#   [28.125, 28.125, 88.125, 88.125],
#   [135.0, 135.0, 145.0, 145.0],
#   [155.0, 155.0, 165.0, 165.0],
#   
#   [0.0, 0.5847986859822798, 0.5847986859822798, 0.0],
#   [0.0, 0.21713085398238666, 0.21713085398238666, 0.0],
#   [0.0, 0.8003321502545694, 0.8003321502545694, 0.21713085398238666],
#   [0.5847986859822798,
#    1.3835424984026339,
#    1.3835424984026339,
#    0.8003321502545694],
#   [0.0, 1.732972527199607, 1.732972527199607, 1.3835424984026339],
#   [1.6410265967237383,
#    2.9469239570134844,
#    2.9469239570134844,
#    1.732972527199607],
#   [0.6245373116758045,
#    3.6131326730893267,
#    3.6131326730893267,
#    2.9469239570134844],
#   [0.0, 0.4754835429873375, 0.4754835429873375, 0.0],
#   [0.0, 1.0306779655613287, 1.0306779655613287, 0.4754835429873375],
#   [0.0, 0.5230541608015576, 0.5230541608015576, 0.0],
#   [0.0, 1.0582566668683917, 1.0582566668683917, 0.0],
#   [0.5230541608015576,
#    1.558689228358308,
#    1.558689228358308,
#    1.0582566668683917],
#   [1.0306779655613287,
#    2.3390944931603594,
#    2.3390944931603594,
#    1.558689228358308],
#   [0.0, 0.29908898775932896, 0.29908898775932896, 0.0],
#   [0.0, 0.6403193719473629, 0.6403193719473629, 0.29908898775932896],
#   [0.0, 0.5114122289476922, 0.5114122289476922, 0.0],
#   [0.0, 1.089036736451101, 1.089036736451101, 0.5114122289476922],
#   [0.0, 2.1896082498920753, 2.1896082498920753, 1.089036736451101],
#   [0.6403193719473629,
#    2.9836828296967117,
#    2.9836828296967117,
#    2.1896082498920753],
#   [2.3390944931603594,
#    4.212390098685482,
#    4.212390098685482,
#    2.9836828296967117],
#   [3.6131326730893267,
#    5.950445645970829,
#    5.950445645970829,
#    4.212390098685482],
#   [3.6710485012991327,
#    7.773398135838125,
#    7.773398135838125,
#    5.950445645970829],
#   [2.8996502865987894,
#    10.768984223049108,
#    10.768984223049108,
#    7.773398135838125],
#   [9.282710298676996,
#    14.994231262100389,
#    14.994231262100389,
#    10.768984223049108],
#   [7.2623951908774815,
#    17.743593235329893,
#    17.743593235329893,
#    14.994231262100389]],
#  'ivl': ['42',
#   '24',
#   '37',
#   '66',
#   '3',
#   '43',
#   '73',
#   '93',
#   '78',
#   '91',
#   '89',
#   '17',
#   '69',
#   '36',
#   '61',
#   '11',
#   '13',
#   '34',
#   '68',
#   '27',
#   '18',
#   '81',
#   '88',
#   '33',
#   '87',
#   '94',
#   '60',
#   '19',
#   '82',
#   '40',
#   '4',
#   '52',
#   '67',
#   '41',
#   '31',
#   '75',
#   '7',
#   '46',
#   '20',
#   '53',
#   '30',
#   '9',
#   '45',
#   '29',
#   '80',
#   '35',
#   '1',
#   '23',
#   '58',
#   '79',
#   '63',
#   '12',
#   '71',
#   '38',
#   '44',
#   '14',
#   '47',
#   '32',
#   '77',
#   '6',
#   '56',
#   '28',
#   '55',
#   '50',
#   '15',
#   '90',
#   '48',
#   '97',
#   '49',
#   '0',
#   '25',
#   '26',
#   '21',
#   '59',
#   '16',
#   '84',
#   '10',
#   '85',
#   '70',
#   '98',
#   '86',
#   '2',
#   '22',
#   '8',
#   '74',
#   '96',
#   '95',
#   '39',
#   '57',
#   '65',
#   '99',
#   '64',
#   '83',
#   '92',
#   '54',
#   '62',
#   '51',
#   '76',
#   '5',
#   '72'],
#  'leaves': [42,
#   24,
#   37,
#   66,
#   3,
#   43,
#   73,
#   93,
#   78,
#   91,
#   89,
#   17,
#   69,
#   36,
#   61,
#   11,
#   13,
#   34,
#   68,
#   27,
#   18,
#   81,
#   88,
#   33,
#   87,
#   94,
#   60,
#   19,
#   82,
#   40,
#   4,
#   52,
#   67,
#   41,
#   31,
#   75,
#   7,
#   46,
#   20,
#   53,
#   30,
#   9,
#   45,
#   29,
#   80,
#   35,
#   1,
#   23,
#   58,
#   79,
#   63,
#   12,
#   71,
#   38,
#   44,
#   14,
#   47,
#   32,
#   77,
#   6,
#   56,
#   28,
#   55,
#   50,
#   15,
#   90,
#   48,
#   97,
#   49,
#   0,
#   25,
#   26,
#   21,
#   59,
#   16,
#   84,
#   10,
#   85,
#   70,
#   98,
#   86,
#   2,
#   22,
#   8,
#   74,
#   96,
#   95,
#   39,
#   57,
#   65,
#   99,
#   64,
#   83,
#   92,
#   54,
#   62,
#   51,
#   76,
#   5,
#   72],
#  'color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C0',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C0',
#   'C0',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4'],
#  'order_rows': array(['42', '24', '37', '66', '3', '43', '73', '93', '78', '91', '89',
#         '17', '69', '36', '61', '11', '13', '34', '68', '27', '18', '81',
#         '88', '33', '87', '94', '60', '19', '82', '40', '4', '52', '67',
#         '41', '31', '75', '7', '46', '20', '53', '30', '9', '45', '29',
#         '80', '35', '1', '23', '58', '79', '63', '12', '71', '38', '44',
#         '14', '47', '32', '77', '6', '56', '28', '55', '50', '15', '90',
#         '48', '97', '49', '0', '25', '26', '21', '59', '16', '84', '10',
#         '85', '70', '98', '86', '2', '22', '8', '74', '96', '95', '39',
#         '57', '65', '99', '64', '83', '92', '54', '62', '51', '76', '5',
#         '72'], dtype='<U2'),
#  'labx': array([10,  6, 11,  1,  3, 13,  9,  4, 11,  5, 11,  2,  7,  2,  8,  9, 11,
#          1,  2,  3,  5, 11, 11,  6,  1, 10, 11,  2,  9,  6,  5,  4,  8,  3,
#          2,  6,  2,  1,  8, 12,  3,  4,  1,  1,  8,  5,  4,  8, 10, 10,  9,
#         13,  3,  5, 13,  9,  9, 12,  6, 11,  3,  2, 13,  7, 12, 12,  1,  4,
#          2,  1, 11,  7, 13,  1, 11,  4, 13,  8,  1,  6,  6,  2,  3, 12, 11,
#         11, 11,  3,  2,  1,  9,  1, 13,  1,  3, 12, 11, 10, 11, 12],
#        dtype=int32),
#  'max_d': 3.6905654035314917,
#  'max_d_lower': 3.6710485012991327,
#  'max_d_upper': 3.7100823057638506,
#  'ax': <AxesSubplot:title={'center':'Hierarchical Clustering Dendrogram'}, xlabel='Samples', ylabel='distance'>}

# %%
# Determine the optimal number of clusters
ce = clusteval(method='derivative')
ce.fit(X)
ce.plot()
ce.scatter(X)
ce.dendrogram()
# Out:
# [clusteval] >Fit using agglomerative with metric: euclidean, and linkage: ward
# [clusteval] >Evaluate using derivatives.
# [clusteval] >Determining optimal clustering by derivatives..
# [clusteval] >Clusters: 5
# [clusteval] >Compute dendrogram threshold.
# [clusteval] >Optimal number clusters detected: [5].
# [clusteval] >Fin.
# [clusteval] >Estimated number of n_clusters: 5, average silhouette_score=0.265
# [clusteval] >Plotting the dendrogram with optimized settings: metric=euclidean, linkage=ward, max_d=8.528. Be patient now..
# [clusteval] >Compute cluster labels.
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [45.0, 45.0, 60.0, 60.0],
#   [35.0, 35.0, 52.5, 52.5],
#   [12.5, 12.5, 43.75, 43.75],
#   [85.0, 85.0, 95.0, 95.0],
#   [115.0, 115.0, 125.0, 125.0],
#   [105.0, 105.0, 120.0, 120.0],
#   [90.0, 90.0, 112.5, 112.5],
#   [75.0, 75.0, 101.25, 101.25],
#   [28.125, 28.125, 88.125, 88.125],
#   [135.0, 135.0, 145.0, 145.0],
#   [155.0, 155.0, 165.0, 165.0],
#   [140.0, 140.0, 160.0, 160.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [215.0, 215.0, 225.0, 225.0],
#   [205.0, 205.0, 220.0, 220.0],
#   [195.0, 195.0, 212.5, 212.5],
#   [180.0, 180.0, 203.75, 203.75],
#   [150.0, 150.0, 191.875, 191.875],
#   [245.0, 245.0, 255.0, 255.0],
#   [275.0, 275.0, 285.0, 285.0],
#   [265.0, 265.0, 280.0, 280.0],
#   [250.0, 250.0, 272.5, 272.5],
#   [235.0, 235.0, 261.25, 261.25],
#   [305.0, 305.0, 315.0, 315.0],
#   [295.0, 295.0, 310.0, 310.0],
#   [248.125, 248.125, 302.5, 302.5],
#   [170.9375, 170.9375, 275.3125, 275.3125],
#   [58.125, 58.125, 223.125, 223.125],
#   [365.0, 365.0, 375.0, 375.0],
#   [355.0, 355.0, 370.0, 370.0],
#   [345.0, 345.0, 362.5, 362.5],
#   [335.0, 335.0, 353.75, 353.75],
#   [325.0, 325.0, 344.375, 344.375],
#   [385.0, 385.0, 395.0, 395.0],
#   [415.0, 415.0, 425.0, 425.0],
#   [405.0, 405.0, 420.0, 420.0],
#   [390.0, 390.0, 412.5, 412.5],
#   [334.6875, 334.6875, 401.25, 401.25],
#   [435.0, 435.0, 445.0, 445.0],
#   [465.0, 465.0, 475.0, 475.0],
#   [485.0, 485.0, 495.0, 495.0],
#   [470.0, 470.0, 490.0, 490.0],
#   [455.0, 455.0, 480.0, 480.0],
#   [440.0, 440.0, 467.5, 467.5],
#   [515.0, 515.0, 525.0, 525.0],
#   [505.0, 505.0, 520.0, 520.0],
#   [535.0, 535.0, 545.0, 545.0],
#   [575.0, 575.0, 585.0, 585.0],
#   [565.0, 565.0, 580.0, 580.0],
#   [555.0, 555.0, 572.5, 572.5],
#   [540.0, 540.0, 563.75, 563.75],
#   [512.5, 512.5, 551.875, 551.875],
#   [453.75, 453.75, 532.1875, 532.1875],
#   [367.96875, 367.96875, 492.96875, 492.96875],
#   [615.0, 615.0, 625.0, 625.0],
#   [605.0, 605.0, 620.0, 620.0],
#   [595.0, 595.0, 612.5, 612.5],
#   [645.0, 645.0, 655.0, 655.0],
#   [635.0, 635.0, 650.0, 650.0],
#   [603.75, 603.75, 642.5, 642.5],
#   [695.0, 695.0, 705.0, 705.0],
#   [685.0, 685.0, 700.0, 700.0],
#   [675.0, 675.0, 692.5, 692.5],
#   [665.0, 665.0, 683.75, 683.75],
#   [725.0, 725.0, 735.0, 735.0],
#   [715.0, 715.0, 730.0, 730.0],
#   [745.0, 745.0, 755.0, 755.0],
#   [765.0, 765.0, 775.0, 775.0],
#   [785.0, 785.0, 795.0, 795.0],
#   [770.0, 770.0, 790.0, 790.0],
#   [750.0, 750.0, 780.0, 780.0],
#   [815.0, 815.0, 825.0, 825.0],
#   [845.0, 845.0, 855.0, 855.0],
#   [835.0, 835.0, 850.0, 850.0],
#   [820.0, 820.0, 842.5, 842.5],
#   [805.0, 805.0, 831.25, 831.25],
#   [765.0, 765.0, 818.125, 818.125],
#   [722.5, 722.5, 791.5625, 791.5625],
#   [875.0, 875.0, 885.0, 885.0],
#   [865.0, 865.0, 880.0, 880.0],
#   [895.0, 895.0, 905.0, 905.0],
#   [915.0, 915.0, 925.0, 925.0],
#   [900.0, 900.0, 920.0, 920.0],
#   [872.5, 872.5, 910.0, 910.0],
#   [945.0, 945.0, 955.0, 955.0],
#   [935.0, 935.0, 950.0, 950.0],
#   [985.0, 985.0, 995.0, 995.0],
#   [975.0, 975.0, 990.0, 990.0],
#   [965.0, 965.0, 982.5, 982.5],
#   [942.5, 942.5, 973.75, 973.75],
#   [891.25, 891.25, 958.125, 958.125],
#   [757.03125, 757.03125, 924.6875, 924.6875],
#   [674.375, 674.375, 840.859375, 840.859375],
#   [623.125, 623.125, 757.6171875, 757.6171875],
#   [430.46875, 430.46875, 690.37109375, 690.37109375],
#   [140.625, 140.625, 560.419921875, 560.419921875]],
#  'dcoord': [[0.0, 0.23899517171789636, 0.23899517171789636, 0.0],
#   [0.0, 0.5634206797898659, 0.5634206797898659, 0.23899517171789636],
#   [0.0, 0.5129338564689876, 0.5129338564689876, 0.0],
#   [0.0, 0.6523901230028649, 0.6523901230028649, 0.5129338564689876],
#   [0.0, 1.033881436385659, 1.033881436385659, 0.6523901230028649],
#   [0.5634206797898659,
#    1.7791612246768058,
#    1.7791612246768058,
#    1.033881436385659],
#   [0.0, 0.3196386157934817, 0.3196386157934817, 0.0],
#   [0.0, 0.4497790362121057, 0.4497790362121057, 0.0],
#   [0.0, 0.4856443856591082, 0.4856443856591082, 0.4497790362121057],
#   [0.3196386157934817,
#    1.0429905619295738,
#    1.0429905619295738,
#    0.4856443856591082],
#   [0.0, 2.5333651499572443, 2.5333651499572443, 1.0429905619295738],
#   [1.7791612246768058, 3.57344451520298, 3.57344451520298, 2.5333651499572443],
#   [0.0, 0.33755864562672555, 0.33755864562672555, 0.0],
#   [0.0, 0.5868076901311237, 0.5868076901311237, 0.0],
#   [0.33755864562672555,
#    0.8800887276577402,
#    0.8800887276577402,
#    0.5868076901311237],
#   [0.0, 0.3995599310679202, 0.3995599310679202, 0.0],
#   [0.0, 0.6724617311398567, 0.6724617311398567, 0.0],
#   [0.0, 0.7329307961228984, 0.7329307961228984, 0.6724617311398567],
#   [0.0, 1.2779988230248838, 1.2779988230248838, 0.7329307961228984],
#   [0.3995599310679202,
#    1.6290570490462006,
#    1.6290570490462006,
#    1.2779988230248838],
#   [0.8800887276577402,
#    2.2496824243463944,
#    2.2496824243463944,
#    1.6290570490462006],
#   [0.0, 0.2782341328314474, 0.2782341328314474, 0.0],
#   [0.0, 0.18347983192849548, 0.18347983192849548, 0.0],
#   '24',
#   '37',
#   '66',
#   '3',
#   '43',
#   '73',
#   '93',
#   '78',
#   '91',
#   '89',
#   '17',
#   '69',
#   '36',
#   '61',
#   '11',
#   '13',
#   '34',
#   '68',
#   '27',
#   '18',
#   '81',
#   '88',
#   '33',
#   '87',
#   '94',
#   '60',
#   '19',
#   '82',
#   '40',
#   '4',
#   '52',
#   '67',
#   '41',
#   '31',
#   '75',
#   '7',
#   '46',
#   '20',
#   '53',
#   '30',
#   '9',
#   '45',
#   '29',
#   '80',
#   '35',
#   '1',
#   '23',
#   '58',
#   '79',
#   '63',
#   '12',
#   '71',
#   '38',
#   '44',
#   '14',
#   '47',
#   '32',
#   '77',
#   '6',
#   '56',
#   '28',
#   '55',
#   '50',
#   '15',
#   '90',
#   '48',
#   '97',
#   '49',
#   '0',
#   '25',
#   '26',
#   '21',
#   '59',
#   '16',
#   '84',
#   '10',
#   '85',
#   '70',
#   '98',
#   '86',
#   '2',
#   '22',
#   '8',
#   '74',
#   '96',
#   '95',
#   '39',
#   '57',
#   '65',
#   '99',
#   '64',
#   '83',
#   '92',
#   '54',
#   '62',
#   '51',
#   '76',
#   '5',
#   '72'],
#  'leaves': [42,
#   24,
#   37,
#   66,
#   3,
#   43,
#   73,
#   93,
#   78,
#   91,
#   89,
#   17,
#   69,
#   36,
#   61,
#   11,
#   13,
#   34,
#   68,
#   27,
#   18,
#   81,
#   88,
#   33,
#   87,
#   94,
#   60,
#   19,
#   82,
#   40,
#   4,
#   52,
#   67,
#   41,
#   31,
#   75,
#   7,
#   46,
#   20,
#   53,
#   30,
#   9,
#   45,
#   29,
#   80,
#   35,
#   1,
#   23,
#   58,
#   79,
#   63,
#   12,
#   71,
#   38,
#   44,
#   14,
#   47,
#   32,
#   77,
#   6,
#   56,
#   28,
#   55,
#   50,
#   15,
#   90,
#   48,
#   97,
#   49,
#   0,
#   25,
#   26,
#   21,
#   59,
#   16,
#   84,
#   10,
#   85,
#   70,
#   98,
#   86,
#   2,
#   22,
#   8,
#   74,
#   96,
#   95,
#   39,
#   57,
#   65,
#   99,
#   64,
#   83,
#   92,
#   54,
#   62,
#   51,
#   76,
#   5,
#   72],
#  'color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C2',
#   'C1'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3'],
#  'order_rows': array(['42', '24', '37', '66', '3', '43', '73', '93', '78', '91', '89',
#         '17', '69', '36', '61', '11', '13', '34', '68', '27', '18', '81',
#         '88', '33', '87', '94', '60', '19', '82', '40', '4', '52', '67',
#         '41', '31', '75', '7', '46', '20', '53', '30', '9', '45', '29',
#         '80', '35', '1', '23', '58', '79', '63', '12', '71', '38', '44',
#         '14', '47', '32', '77', '6', '56', '28', '55', '50', '15', '90',
#         '48', '97', '49', '0', '25', '26', '21', '59', '16', '84', '10',
#         '85', '70', '98', '86', '2', '22', '8', '74', '96', '95', '39',
#         '57', '65', '99', '64', '83', '92', '54', '62', '51', '76', '5',
#         '72'], dtype='<U2'),
#  'labx': array([5, 3, 5, 1, 1, 5, 4, 2, 5, 2, 5, 1, 3, 1, 3, 4, 5, 1, 1, 1, 2, 5,
#         5, 3, 1, 5, 5, 1, 4, 3, 2, 2, 3, 1, 1, 3, 1, 1, 3, 5, 1, 2, 1, 1,
#         3, 2, 2, 3, 5, 5, 4, 5, 1, 2, 5, 4, 4, 5, 3, 5, 1, 1, 5, 3, 5, 5,
#         1, 2, 1, 1, 5, 3, 5, 1, 5, 2, 5, 3, 1, 3, 3, 1, 1, 5, 5, 5, 5, 1,
#         1, 1, 4, 1, 5, 1, 1, 5, 5, 5, 5, 5], dtype=int32),
#  'max_d': 8.52805421725756,
#  'max_d_lower': 7.773398135838125,
#  'max_d_upper': 9.282710298676996,
#  'ax': <AxesSubplot:title={'center':'Hierarchical Clustering Dendrogram'}, xlabel='Samples', ylabel='distance'>}

# %%
# Determine the optimal number of clusters using dbscan and silhoutte
ce = clusteval(cluster='dbscan')
ce.fit(X)
ce.plot()
ce.scatter(X)
ce.dendrogram()
# Out:
# [clusteval] >Fit using dbscan with metric: euclidean, and linkage: ward
# [clusteval] >Normalize data (unit variance, zero-mean).
# [clusteval] >Gridsearch across epsilon..
# [clusteval] >Evaluate using silhouette..
#   0%|          | 0/245 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22032/62651244.py in <module>
#       1 # Determine the optimal number of clusters using dbscan and silhoutte
#       2 ce = clusteval(cluster='dbscan')
# ----> 3 ce.fit(X)
#       4 ce.plot()
#       5 ce.scatter(X)
#
# ~\.conda\envs\tf-gpu\lib\site-packages\clusteval\clusteval.py in fit(self, X)
#     159                 self.results = derivative.fit(X, Z=self.Z, cluster=self.cluster, metric=self.metric, min_clust=self.min_clust, max_clust=self.max_clust, verbose=self.verbose)
#     160         elif (self.cluster=='dbscan') and (self.method=='silhouette'):
# --> 161             self.results = dbscan.fit(X, eps=None, epsres=50, min_samples=0.01, metric=self.metric, norm=True, n_jobs=-1, min_clust=self.min_clust, max_clust=self.max_clust, verbose=self.verbose)
#     162         elif self.cluster=='hdbscan':
#     163             try:
#
# ~\.conda\envs\tf-gpu\lib\site-packages\clusteval\dbscan.py in fit(X, eps, min_samples, metric, norm, n_jobs, min_clust, max_clust, epsres, verbose)
#      93         if Param['verbose']>=3: print('[clusteval] >Gridsearch across epsilon..')
#      94         # Optimize
# ---> 95         [eps, sillclust, silscores, silllabx] = _optimize_eps(X, eps, Param, verbose=verbose)
#      96         # Store results
#      97         idx = np.argmax(silscores)
#
# ~\.conda\envs\tf-gpu\lib\site-packages\clusteval\dbscan.py in _optimize_eps(X, eps, Param, verbose)
#     137         # Compute Silhouette only if more then 1 cluster
#     138         if sillclust[i]>1:
# --> 139             silscores[i] = silhouette_score(X, db.labels_)
#     140
#     141     # Convert to array
#
# ~\.conda\envs\tf-gpu\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     116         else:
#     117             X, labels = X[indices], labels[indices]
# --> 118     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     119
#     120
#
# ~\.conda\envs\tf-gpu\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     227     n_samples = len(labels)
#     228     label_freqs = np.bincount(labels)
# --> 229     check_number_of_labels(len(le.classes_), n_samples)
#     230
#     231     kwds["metric"] = metric
#
# ~\.conda\envs\tf-gpu\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py in check_number_of_labels(n_labels, n_samples)
#      31     """
#      32     if not 1 < n_labels < n_samples:
# ---> 33         raise ValueError(
#      34             "Number of labels is %d. Valid values are 2 to n_samples - 1 (inclusive)"
#      35             % n_labels
#
# ValueError: Number of labels is 100. Valid values are 2 to n_samples - 1 (inclusive)
